# %% [markdown]
# <a href="https://colab.research.google.com/github/bigdatakang0000/START/blob/main/%ED%85%8D%EC%8A%A4%ED%8A%B8%EB%A7%88%EC%9D%B4%EB%8B%9D_busan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
article_txt = open("/content/drive/MyDrive/유비온/article_busan.txt", "rt",encoding = "UTF-8").read()

# %%
article_txt
# Out:
# "지역 기반 미디어의 하이퍼 로컬리즘과 지역성 범주 변화\n부산 지역 기반 유튜브 채널 운영자에 대한 심층 인터뷰\n강주현 부산대학교 지역혁신역량교육연구센터 연구교수\nHyper-Localism in Local Media and Changes in the Category\nof Locality*\n,**\n\nIn-Depth Interview with a Busan-Based YouTube Channel Operator\nJu Hyun Kang***\n(Research Professor, Regional Entrepreneurship Education Research Center, Pusan National University)\nThis study investigated the characteristics of local media based on Busan from a vantage point of\nhyperlocal media, a concept based in Western society. In-depth interviews were conducted with 11\npeople, including a YouTube channel operator who produces content for the YouTube platform in\nBusan, a YouTube channel operator of a local media, and an activist of a local media civic group.\nFirst, the concept of locality assumes a geographical basis in that the content creators are located in a\nparticular region, but in the new media environment, the locality of content creators is no longer\nconfined to the geography in which administ
# ...

# %%
from konlpy.tag import Okt
from collections import Counter

# %%
okt = Okt()
line = []

line = okt.pos(article_txt)
n_adj = []
for word, tag in line:
    if tag in ["Noun", "Adjective"]:
       n_adj.append(word)
print(n_adj)
# Out:
# ['지역', '기반', '미디어', '하이퍼', '로컬', '리즘', '지역성', '범주', '변화', '부산', '지역', '기반', '유튜브', '채널', '운영자', '대한', '심층', '인터뷰', '강주현', '부산대학교', '지역', '혁신', '역량', '교육', '연구', '센터', '연구', '교수', '이', '연구', '한국', '방송', '학회', '신진', '학자', '특별', '비지', '사업', '한국', '방송', '학회', '의해', '수행', '이', '논문', '대한민국', '교육부', '한국', '연구', '재단', '지원', '수행', '한국', '언론', '학보', '권', '호', '쪽', '한국', '언론', '학보', '권', '호', '지역', '기반', '미디어', '하이퍼', '로컬', '리즘', '지역성', '범주', '변화', '지역', '미디어', '방향성', '생존', '전략', '찾기', '현대', '사회', '지역', '단위', '공동체', '가능한가', '굳이', '그것', '필요한가', '혹', '나', '그것', '가능하고', '필요하다면', '그', '이유', '무엇', '지역', '공동체', '속성', '방향성', '무엇', '김미영', '은', '공동체', '란', '사회', '조직', '소속', '형태', '전통', '가치', '사회', '일', '때', '존재', '수', '있으며', '바람직한', '변화', '추', '역할', '수', '있다고', '설명', '여기', '공동체', '란', '동일성', '확실성', '속성', '아니라', '차이', '우연', '것', '지역', '공동체', '그런', '가치', '지향', '일', '때', '구성원', '각', '자의', '연대', '통해', '존재', '수', '있다', '온라인', '연결', '글로벌', '교통', '수단', '발달', '오늘날', '왜', '지역', '공동체', '화두', '수', '있', '는가', '오늘날'
# ...

# %%
stop_words = "있습니다. 를 로 수 때문"
stop_words = set(stop_words.split("  "))
n_adj =[word for word in n_adj if not word in stop_words]

# %%
counts = Counter(n_adj)
tags = counts.most_common(20)
print(counts)
print(tags)
# Out:
# Counter({'지역': 589, '미디어': 305, '콘텐츠': 201, '유튜브': 162, '수': 154, '채널': 150, '이': 147, '시민': 146, '제작': 117, '사람': 88, '등': 84, '기반': 81, '언론': 81, '하이퍼': 74, '지역성': 73, '참여': 73, '있다': 70, '전통': 69, '부산': 65, '그': 64, '컬': 63, '뉴스': 58, '이용자': 58, '로컬': 57, '연구': 55, '운영': 52, '변화': 51, '한국': 51, '있는': 51, '방송': 49, '때문': 48, '점': 44, '호': 43, '사회': 42, '환경': 42, '인터뷰': 41, '것': 40, '명': 40, '때': 37, '권': 36, '대한': 35, '의': 35, '내용': 35, '은': 34, '매체': 33, '정보': 33, '프로그램': 33, '영상': 32, '학보': 31, '활동': 31, '있었다': 31, '조회': 30, '말': 28, '글': 28, '리즘': 27, '범주': 27, '중심': 27, '새로운': 27, '제공': 26, '심층': 25, '공동체': 25, '문제': 25, '더': 25, '제작자': 25, '통해': 24, '위해': 24, '플랫폼': 24, '또한': 24, '온라인': 23, '어떻게': 22, '과정': 22, '신문': 22, '전국': 22, '가치': 21, '역할': 20, '이슈': 20, '특징': 20, '경우': 20, '이야기': 20, '시간': 20, '운영자': 19, '지원': 19, '공간': 19, '위': 19, '있다고': 18, '문화': 18, '저널리즘': 18, '소개': 18, '역시': 18, '대상': 18, '그것': 17, '다른': 17, '필요': 17, '비판': 17, '인권': 17, '삶': 16, '활성화': 16, '지적': 
# ...

# %%
from wordcloud import WordCloud

# %%
font = "/content/drive/MyDrive/유비온/malgun/malgun.ttf"
word_cloud = WordCloud(font_path=font,
                       background_color="black",
                       max_font_size=300,
                       colormap="prism").generate_from_frequencies(dict(tags))
import matplotlib.pyplot as plt
plt.figure(figsize = (10,8))
plt.imshow(word_cloud)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)
