# %% [markdown]
# <a href="https://colab.research.google.com/github/bigdatakang0000/START/blob/main/%ED%85%8D%EC%8A%A4%ED%8A%B8%EB%A7%88%EC%9D%B4%EB%8B%9D_%EC%9C%A0%ED%8A%9C%EB%B8%8C%EB%8C%93%EA%B8%80%EB%B6%84%EC%84%9Dkang.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
article_txt = open("/content/drive/MyDrive/유비온/package.txt", "rt",encoding = "UTF-8").read()

# %%
article_txt
# Out:
# '좋은 제도입니다! 꼭 잘 운용되길 바래요~~~~~\n\n\n늘 유용한 정보 감사해요.\n\n\n볼때마다 느끼는데 분명 좋은 제도들이 많은데 나한테 적용되는건 없음. 어떤 복지를 받으려면 여러 조건들을 충족시켜야 하는데 죄다 1개2개씩 해당이 안됨. 내가 볼때 어중간한 하층민들은 나라배움카드 빼고는 받을 복지가 하나도 없음 ㅋㅋㅋㅋㅋㅋ정책 입안자들이 일부러 못먹는 떡을 보여주는거같음. 한마디로 지독하게 가난하거나 노인층 아닌 이상 복지 없다고 보면 됩니다\n\n\n유용한 정보네요~감사합니다!\n\n좋은 정보 감사합니다.\n\n오늘도 유익한 정보 감사합니다 ~. ^^^\n\n\n늘 좋은소식 감사합니다\n\n복지마블님 저 오늘\n사복1급 가채점결과 합격입니다\n복지마블님 영상 보고\n동기부여가 되었는데\n합격하면 꼭 자랑하고 싶었네요\n\n\n\n\n진짜감사합니다 역시스텔라님 바로신청할께요!!\n참 좋은 제도입니다~ 화이팅\n답글\n\n\n좋은소식이네요~^^\n\n\n좋은소식이네요\n\n아웃소싱의 취업방해 때문에 양쪽이 손해\n\n감솨합니다\n\n인건비 후려치고 \n20대만 구하려고 하는 악덕기업들...\n\n\n좋은 제도입니다만 과거 경력개발 패키지를 경험한 이로서 한마디하면 당시 대면상담하면서 설문조사 형식처럼 뭔가 작성하게하고 관련 업체 안내만 열심히 해주었네요....실질적으로 도움이 안되었습니다.  한편으로 경력을 바탕으로 하여 앞으로 어떤 진로를 결정할지 고민하던 저에게 당시 고용노동부 온라인 상담은 유익했습니다.  아뭏든 풀 패키지 제도가 당사자에게 형식적이 아닌 실질적 도움이 되기를 바랍니다.\n\n양스텔라님 안녕하세요 \n오늘도 좋은 정보 감사드립니다 \n영상 잘 봤고요 편안한 시간 보내세요 \n응원 드립니다 🙇\u200d♂️\n\n극한의 20%정도로 살아야 하는듯\n\n출퇴슨 확실하고 월급 밀리지만 않으면  땡큐인데..\n\n저 얼마전 국민 취업 그거 신청하러 고용센터 갔었는데 부모님 재산 때문에 거절당했습니다 2유형은 의미 없고 1유형이 제일
# ...

# %%
from konlpy.tag import Okt
from collections import Counter

# %%
okt = Okt()
line = []

line = okt.pos(article_txt)
n_adj = []
for word, tag in line:
    if tag in ["Noun", "Adjective"]:
       n_adj.append(word)
print(n_adj)
# Out:
# ['좋은', '제도', '입니다', '꼭', '운용', '바', '요', '늘', '유용한', '정보', '볼때', '분명', '좋은', '제도', '많은데', '나', '적용', '없음', '어떤', '복지', '여러', '조건', '충족', '개', '개', '해당', '안됨', '내', '볼때', '어중간한', '하층', '민', '나라', '배움', '카드', '복지', '하나', '없음', '정책', '입안', '일부러', '떡', '같음', '한마디', '지독하게', '가난하거나', '노인', '층', '아닌', '이상', '복지', '없다고', '유용한', '정보', '좋은', '정보', '오늘', '유익한', '정보', '늘', '좋은', '소식', '복지', '마블', '저', '오늘', '사복', '급', '채점', '결과', '합격', '입니다', '복지', '마블', '영상', '보고', '동기부여', '합격', '꼭', '자랑', '진짜', '역시', '스텔라', '바로', '신청', '좋은', '제도', '입니다', '화이팅', '답글', '좋은', '식이', '좋은', '식이', '아웃소싱', '취업', '방해', '때문', '양쪽', '손해', '감솨', '인건비', '후려', '대만', '구', '악덕', '기업', '좋은', '제도', '입니다만', '과거', '경력', '개발', '패키지', '경험', '이로', '한마디', '당시', '대면', '담하면서', '설문조사', '형식', '뭔가', '작성', '관련', '업체', '안내', '실질', '도움', '안되었습니다', '한편', '경력', '바탕', '앞', '어떤', '진로', '결정', '고민', '저', '당시', '고용노동부', '온라인', '상담', '유익했습니다', '아뭏', '풀', '패키지', '제도', '당사자', '형식', '아닌', '실질', '도움', '스텔라', '안녕하세요', '오늘', '좋은', '정보', '감사', '영상', '편안한',
# ...

# %%
stop_words = "있습니다. 를 로 수 때문"
stop_words = set(stop_words.split("  "))
n_adj =[word for word in n_adj if not word in stop_words]

# %%
counts = Counter(n_adj)
tags = counts.most_common(20)
print(counts)
print(tags)
# Out:
# Counter({'좋은': 9, '제도': 7, '기업': 7, '취업': 6, '정보': 5, '복지': 5, '신청': 5, '패키지': 5, '도움': 5, '업체': 4, '재산': 4, '지원': 4, '입니다': 3, '나라': 3, '오늘': 3, '저': 3, '진짜': 3, '때문': 3, '구': 3, '실질': 3, '부모님': 3, '탈락': 3, '것': 3, '서류': 3, '경기도': 3, '사업': 3, '일자리': 3, '꼭': 2, '요': 2, '늘': 2, '유용한': 2, '볼때': 2, '없음': 2, '어떤': 2, '개': 2, '내': 2, '정책': 2, '한마디': 2, '아닌': 2, '이상': 2, '마블': 2, '합격': 2, '영상': 2, '보고': 2, '스텔라': 2, '식이': 2, '인건비': 2, '경력': 2, '당시': 2, '형식': 2, '뭔가': 2, '풀': 2, '전': 2, '국민': 2, '그거': 2, '유형': 2, '제일': 2, '개인': 2, '어려운': 2, '위해': 2, '이': 2, '국가': 2, '뭐': 2, '임': 2, '정말': 2, '있음': 2, '마찬가지': 2, '그': 2, '그렇고': 2, '또': 2, '비슷한': 2, '운영': 2, '운용': 1, '바': 1, '분명': 1, '많은데': 1, '나': 1, '적용': 1, '여러': 1, '조건': 1, '충족': 1, '해당': 1, '안됨': 1, '어중간한': 1, '하층': 1, '민': 1, '배움': 1, '카드': 1, '하나': 1, '입안': 1, '일부러': 1, '떡': 1, '같음': 1, '지독하게': 1, '가난하거나': 1, '노인': 1, '층': 1, '없다고': 1, '유익한': 1, '소식': 1, '사복': 1, '급': 1, '채점': 1, '결과': 1, '동기부여': 1, '자랑': 1, '역시': 1, '바로': 1, '화이팅': 1, '
# ...

# %%
from wordcloud import WordCloud

# %%
font = "/content/drive/MyDrive/유비온/malgun/malgun.ttf"
word_cloud = WordCloud(font_path=font,
                       background_color="black",
                       max_font_size=300,
                       colormap="prism").generate_from_frequencies(dict(tags))
import matplotlib.pyplot as plt
plt.figure(figsize = (10,8))
plt.imshow(word_cloud)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)
